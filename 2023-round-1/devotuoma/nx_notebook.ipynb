# %% [markdown]
# # Generators for random graphs

# %%
# importing networkx library with the alias nx
import networkx as nx
# importing matplotlib library with the alias plt
import matplotlib.pyplot as plt

# %%
#creating the graph
Random_graph = nx.erdos_renyi_graph(100,0.3)
nx.draw(Random_graph, with_labels=True)
plt.show()

# %% [markdown]
# # Plotting the degree_centrality distribution using histogram.

# %%
def plot_degree_dist(Random_graph):
    degrees = [Random_graph.degree(n) for n in Random_graph.nodes()]
    plt.hist(degrees)
    plt.show()

plot_degree_dist(nx.gnp_random_graph(100, 0.3, directed=True))

# %%
# Changing the edge probability of the erdos-reyni graph to 0.6 and plotting the degree centrality distribution again.
def plot_degree_dist(Random_graph):
    degrees = [Random_graph.degree(n) for n in Random_graph.nodes()]
    plt.hist(degrees)
    plt.show()

plot_degree_dist(nx.gnp_random_graph(100, 0.6, directed=True))

# %% [markdown]
# # Inference from the plots
# Edge probability act as the bridge between the nodes such that when the probability is high or close to 1 the centrality distribution becomes large. Similarly when the edge probability is far from 1 the centrality distribution becomes smaller. This can be clearly seen as the first histrogram plot with edge probability of 0.3 has half centrality distribution as that of the second plot which has the edge probability of 0.6.

# %% [markdown]
# # Creating random barabasi_albert_graph

# %%
# I had imported networkx and matplotlib library but if one is working on a different notebook,the libraries have to be imported again.
m = 3 # edges
Random_graph= nx.barabasi_albert_graph(100,m)
nx.draw(Random_graph, with_labels=True)
plt.show()

# %%
def plot_degree_dist(Random_graph):
    degrees = [Random_graph.degree(n) for n in Random_graph.nodes()]
    plt.hist(degrees)
    plt.show()

plot_degree_dist(nx.barabasi_albert_graph(100, m))

# %% [markdown]
# # Second Inference
# The centrality distribution in the barabasi_albert_graph is of a low range with the first nodes having higher frequency(bridge) and the frequency is higher upto over 40. Edge probability and number affectsd the centrality distribution of the random graph generators of both barabasi_albert_graph and even the erdos-reyni graph. Degree centrality distribution of the barabasi_albert_graph is dependent on the edges number while that of erdos-eyni graph depends on the edge probability i.e the bridge between the nodes.
